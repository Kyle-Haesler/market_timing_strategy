# %%
import sys
from pathlib import Path
# Add project root to Python path
root_dir = Path().resolve().parents[0]
sys.path.append(str(root_dir))


from src.data_loader import download_spy
from src.drawdown_analysis import calculate_drawdowns

spy = download_spy()['Adj Close']
drawdowns = calculate_drawdowns(spy)

# Quick exploration
drawdowns.hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sys
#       2 from pathlib import Path
# ----> 3 from src.data_loader import download_spy
#       4 from src.drawdown_analysis import calculate_drawdowns
#       6 # Add project root to Python path
#
# ModuleNotFoundError: No module named 'src'
